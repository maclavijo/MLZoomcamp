# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dfCredit = pd.read_excel("default of credit card clients.xls", header=1)
dfCredit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.Y.value_counts()
# Out:
# 0                             23364
# 1                              6636
# default payment next month        1
# Name: Y, dtype: int64

# %%
df.isnull().mean()
# Out:
# Unnamed: 0    0.0
# X1            0.0
# X2            0.0
# X3            0.0
# X4            0.0
# X5            0.0
# X6            0.0
# X7            0.0
# X8            0.0
# X9            0.0
# X10           0.0
# X11           0.0
# X12           0.0
# X13           0.0
# X14           0.0
# X15           0.0
# X16           0.0
# X17           0.0
# X18           0.0
# X19           0.0
# X20           0.0
# X21           0.0
# X22           0.0
# X23           0.0
# Y             0.0
# dtype: float64

# %%
df = pd.read_excel('CTG.xls', sheet_name='Data', header=0)
df
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             b          e         AC         FM         UC         DL
# 1           240        357          0          0          0          0
# 2             5        632          4          0          4          2
# 3           177        779          2          0          5          2
# 4           411       1192          2          0          6          2
# ...         ...        ...        ...        ...        ...        ...
# 2125       1576       3049          1          0          9          0
# 2126       2796       3415          1          1          5          0
# 2127        NaN        NaN        NaN        NaN        NaN        NaN
# 2128        NaN        NaN        NaN        NaN        NaN          0
# 2129        NaN        NaN        NaN        564         23         16
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ... Unnamed: 36  \
# ...

# %%
df = pd.read_csv('clinical_data.csv')
df
# Out:
#       caseid  subjectid  casestart  caseend  anestart   aneend  opstart  \
# 0          1       5955          0    11542      -552  10848.0     1668
# 1          2       2487          0    15741     -1039  14921.0     1721
# 2          3       2861          0     4394      -590   4210.0     1090
# 3          4       1903          0    20990      -778  20222.0     2522
# 4          5       4416          0    21531     -1009  22391.0     2591
# ...      ...        ...        ...      ...       ...      ...      ...
# 6383    6384       5583          0    15248      -260  15640.0     2140
# 6384    6385       2278          0    20643      -544  20996.0     2396
# 6385    6386       4045          0    19451      -667  19133.0     3533
# 6386    6387       5230          0    12025      -550  12830.0     1730
# 6387    6388       1306          0    10249       -79  10121.0     2321
#
#       opend     adm      dis  ...  intraop_colloid  intraop_ppf intraop_mdz  \
# ...

# %%
df.columns
# Out:
# Index(['caseid', 'subjectid', 'casestart', 'caseend', 'anestart', 'aneend',
#        'opstart', 'opend', 'adm', 'dis', 'icu_days', 'death_inhosp', 'age',
#        'sex', 'height', 'weight', 'bmi', 'asa', 'emop', 'department', 'optype',
#        'dx', 'opname', 'approach', 'position', 'ane_type', 'preop_htn',
#        'preop_dm', 'preop_ecg', 'preop_pft', 'preop_hb', 'preop_plt',
#        'preop_pt', 'preop_aptt', 'preop_na', 'preop_k', 'preop_gluc',
#        'preop_alb', 'preop_ast', 'preop_alt', 'preop_bun', 'preop_cr',
#        'preop_ph', 'preop_hco3', 'preop_be', 'preop_pao2', 'preop_paco2',
#        'preop_sao2', 'cormack', 'airway', 'tubesize', 'dltubesize', 'lmasize',
#        'iv1', 'iv2', 'aline1', 'aline2', 'cline1', 'cline2', 'intraop_ebl',
#        'intraop_uo', 'intraop_rbc', 'intraop_ffp', 'intraop_crystalloid',
#        'intraop_colloid', 'intraop_ppf', 'intraop_mdz', 'intraop_ftn',
#        'intraop_rocu', 'intraop_vecu', 'intraop_eph', 'intraop_phe',
# ...

# %%
df = pd.read_excel("PUF2021final_v1 (1).xls")
df
# Out:
#        WEIGHT  STATUS  FINALDEST  FOOTINGS  LEASE  REGION  PIERS  SECURED  \
# 0     64.3714       2          1         3      2       3      1        1
# 1     18.0105       2          1         3      2       4      1        1
# 2     18.0105       2          1         3      2       4      3        1
# 3     18.0105       1          1         3      2       4      1        1
# 4     18.0105       2          1         4      2       4      3        1
# ...       ...     ...        ...       ...    ...     ...    ...      ...
# 4923  31.1929       2          2         9      2       3      9        9
# 4924  31.1929       1          2         9      2       3      9        9
# 4925   5.6773       1          2         9      2       2      9        9
# 4926  31.1929       3          9         9      9       5      9        9
# 4927   5.6773       3          9         9      9       5      9        9
#
#       TITLED  SECTIONS  ...  jprice  jsqft  jbedroom  jlease  jfinaldest  \
# ...

# %%
_ = df.PRICE.hist(figsize=(6,4), bins=40)

# %%
newDf = df.copy()
newDf.PRICE = np.log1p(newDf.PRICE)

# %%
_ = newDf.PRICE.hist(figsize=(6,4), bins=40)

# %%
newDf.value_counts()
# Out:
# WEIGHT   STATUS  FINALDEST  FOOTINGS  LEASE  REGION  PIERS  SECURED  TITLED  SECTIONS  PRICE      SQFT  BEDROOMS  LOCATION  SHIPMONTH  WGTADJ  CONTROL   jstatus  jprice  jsqft  jbedroom  jlease  jfinaldest  jtitle  jsecured  jlocation  jfootings  jpiers
# 1.0000   3       9          9         9      5       9      9        9       1         2.302585   9     9         9         202102     1.0240  21020115  R        9       9      9         9       9           9       9         9          9          9         1
# 29.2842  1       2          9         2      3       9      9        9       2         11.608245  1900  3         9         202107     0.9579  21070397  R        R       R      R         R       R           9       9         9          9          9         1
# ...

# %%
dfCredit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
dfCredit.columns = dfCredit.columns.str.replace('default payment next month', 'default')

# %%
dfCredit.columns = dfCredit.columns.str.lower()

# %%
dfCredit.describe()
# Out:
#                  id       limit_bal           sex     education      marriage  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 age         pay_0         pay_2         pay_3         pay_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
dfCredit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         30000 non-null  int64
#  1   limit_bal  30000 non-null  int64
#  2   sex        30000 non-null  int64
#  3   education  30000 non-null  int64
#  4   marriage   30000 non-null  int64
#  5   age        30000 non-null  int64
#  6   pay_0      30000 non-null  int64
#  7   pay_2      30000 non-null  int64
#  8   pay_3      30000 non-null  int64
#  9   pay_4      30000 non-null  int64
#  10  pay_5      30000 non-null  int64
#  11  pay_6      30000 non-null  int64
#  12  bill_amt1  30000 non-null  int64
#  13  bill_amt2  30000 non-null  int64
#  14  bill_amt3  30000 non-null  int64
#  15  bill_amt4  30000 non-null  int64
#  16  bill_amt5  30000 non-null  int64
#  17  bill_amt6  30000 non-null  int64
#  18  pay_amt1   30000 non-null  int64
#  19  pay_amt2   30000 non-null  int64
# ...
