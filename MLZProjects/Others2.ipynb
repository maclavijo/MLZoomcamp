# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_sas('Datasets/LLCP21V3_XPT/LLCP21V3.XPT')
cols = pd.read_excel('Datasets/Dataset_columns.xlsx')
allColumns = cols.cols.to_list()
df.head()

# %%
# Out:
# ['_STATE',
#  '_URBSTAT',
#  '_METSTAT',
#  '_RACE',
#  '_AGEG5YR',
#  '_SEX',
#  'MARITAL',
#  '_EDUCAG',
#  'RENTHOM1',
#  'VETERAN3',
#  'EMPLOY1',
#  '_INCOMG1',
#  'PREGNANT',
#  'HTM4',
#  'WTKG3',
#  '_BMI5CAT',
#  '_RFBMI5',
#  '_BMI5',
#  'HHADULT',
#  'NUMADULT',
#  '_CHLDCNT',
#  'GENHLTH',
#  'PHYSHLTH',
#  'MENTHLTH',
#  'POORHLTH',
#  '_HLTHPLN',
#  'PERSDOC3',
#  'MEDCOST1',
#  'CHECKUP1',
#  '_TOTINDA',
#  '_SMOKER3',
#  '_RFBING5',
#  '_RFDRHV7',
#  'FTJUDA2_',
#  '_FRUTSU1',
#  '_VEGESU1',
#  'VEGEDA2_',
#  'FRNCHDA_',
#  'POTADA1_',
#  '_RFHYPE6',
#  '_RFCHOL3',
#  '_DRDXAR3',
#  '_LMTACT3',
#  '_LMTWRK3',
#  'DIABETE4']

# %%
sns.set_theme()
corrMatrix = df.corr().abs()
plt.figure(figsize=(17,17))

sns.heatmap(corrMatrix, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>
